# %%
import json
from pprint import pprint

with open('swagger.json') as f:
    data = json.load(f)

# Output: {'name': 'Bob', 'languages': ['English', 'Fench']}
pprint(data)
# Out:
# {'components': {'parameters': {'Page': {'description': 'Pagination in the form '
#                                                        'of `page=2` or '
#                                                        '`page[size]=30&page[number]=2`',
#                                         'in': 'query',
#                                         'name': 'page',
#                                         'required': False,
#                                         'schema': {'oneOf': [{'default': 1,
#                                                               'minimum': 1,
#                                                               'type': 'integer'},
#                                                              {'additionalProperties': False,
#                                                               'properties': {'number': {'default': 1,
#                                                                                         'minimum': 1,
# ...
