# %%
import json
from pprint import pprint
import pandas as pd
import os
import matplotlib.pyplot as plt

with open('swagger1.json') as f:
    data = json.load(f)


pprint(data)
# Out:
# {'components': {'parameters': {'Page': {'description': 'Pagination in the form '
#                                                        'of `page=2` or '
#                                                        '`page[size]=30&page[number]=2`',
#                                         'in': 'query',
#                                         'name': 'page',
#                                         'required': False,
#                                         'schema': {'oneOf': [{'default': 1,
#                                                               'minimum': 1,
#                                                               'type': 'integer'},
#                                                              {'additionalProperties': False,
#                                                               'properties': {'number': {'default': 1,
#                                                                                         'minimum': 1,
# ...

# %%
df = pd.json_normalize(data)
df
# Out:
#   openapi                                   security  \
# 0   3.0.0  [{'BearerToken': []}, {'QueryToken': []}]
#
#                                              servers tags  \
# 0  [{'url': 'https://api.pandascore.co/', 'variab...   []
#
#                                          x-tagGroups  \
# 0  [{'name': 'CS:GO', 'tags': ['CSGO games', 'CSG...
#
#               components.parameters.Page.description  \
# 0  Pagination in the form of `page=2` or `page[si...
#
#   components.parameters.Page.in components.parameters.Page.name  \
# 0                         query                            page
#
#    components.parameters.Page.required  \
# 0                                False
#
#              components.parameters.Page.schema.oneOf  ...  \
# 0  [{'default': 1, 'minimum': 1, 'type': 'integer...  ...
#
#   paths./csgo/weapons/{csgo_weapon_id_or_slug}.get.responses.400.$ref  \
# 0                    #/components/responses/Error400
#
# ...
