# %%
# %matplotlib notebook
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_path = "ESportsGames.csv"

games_df = pd.read_csv(csv_path, encoding = "utf-8")
games_df.head()
# Out:
#                     game  releasedate     genre  totalearnings  \
# 0         Age of Empires         1997  Strategy      190262.81
# 1      Age of Empires II         1999  Strategy     1949008.74
# 2     Age of Empires III         2005  Strategy       68613.85
# 3  Age of Empires Online         2011  Strategy        4078.56
# 4       Age of Mythology         2002  Strategy       52360.00
#
#    onlineearnings  totalplayers  totaltournaments
# 0       156839.89           255                96
# 1       619582.87          1357               989
# 2        41500.00           108                77
# 3            0.00            19                12
# 4        52000.00            22                 6

# %%
grouped_by_genre_df = games_df.groupby("genre")
grouped_by_genre_df["genre"].count()
# Out:
# genre
# Battle Royale                       13
# Collectible Card Game               17
# Fighting Game                      171
# First-Person Shooter               107
# Multiplayer Online Battle Arena     23
# Puzzle Game                         15
# Racing                              52
# Role-Playing Game                    6
# Sports                              70
# Strategy                            51
# Third-Person Shooter                10
# Name: genre, dtype: int64

# %%
grouped_by_genre_df["genre"]

# %%
# game_groups = grouped_by_genre_df["genre"].count()

# genre_chart = game_groups.plot(kind = "bar", title = "ESports Games by Genre")
# genre_chart.set_xlabel("Genre")
# genre_chart.set_ylabel("Number of Games")

# plt.show()
# plt.tight_layout()
# plt.savefig("FinalProjectBarGraph1")

game_groups = grouped_by_genre_df["genre"].count()

#game_groups.plot(kind = "bar", title = "ESports Games by Genre")
plt.bar(list(game_groups.index), list(game_groups.values))
plt.xlabel("Genre")
plt.xticks(rotation = 90)
plt.ylabel("Number of Games")

plt.show()
plt.tight_layout()
plt.savefig("FinalProjectBarGraph1")

# %%
player_groups = grouped_by_genre_df["totalplayers"].sum()

game_groups = grouped_by_genre_df["genre"].count()

#game_groups.plot(kind = "bar", title = "ESports Games by Genre")
plt.bar(list(player_groups.index), list(player_groups.values))
plt.xlabel("Genre")
plt.xticks(rotation = 90)
plt.ylabel("Number of Players")

plt.show()
plt.tight_layout()
plt.savefig("FinalProjectBarGraph2")

# %%
fig, axis = plt.subplots(2, 2, figsize = (15, 50))





game_groups = grouped_by_genre_df["genre"].count()


axis[0, 0].bar(list(game_groups.index), list(game_groups.values), color = "blue")
axis[0, 0].set_xlabel("Genre")
plt.setp(axis[0, 0].xaxis.get_majorticklabels(), rotation = 90)
axis[0, 0].set_ylabel("Number of Games")





player_groups = grouped_by_genre_df["totalplayers"].sum()




axis[1, 0].bar(list(player_groups.index), list(player_groups.values), color = "red")
axis[1, 0].set_xlabel("Genre")
plt.setp(axis[1, 0].xaxis.get_majorticklabels(), rotation = 90)
axis[1, 0].set_ylabel("Number of Players")



prize_groups = grouped_by_genre_df["totalearnings"].mean()




axis[0, 1].bar(list(prize_groups.index), list(prize_groups.values), color = "green")
axis[0, 1].set_xlabel("Genre")
plt.setp(axis[0, 1].xaxis.get_majorticklabels(), rotation = 90)
axis[0, 1].set_ylabel("Average Prize Pool")


tournament_groups = grouped_by_genre_df["totaltournaments"].sum()




axis[1, 1].bar(list(tournament_groups.index), list(tournament_groups.values), color = "orange")
axis[1, 1].set_xlabel("Genre")
plt.setp(axis[1, 1].xaxis.get_majorticklabels(), rotation = 90)
axis[1, 1].set_ylabel("Number of Tournaments")

plt.show()
plt.tight_layout()
